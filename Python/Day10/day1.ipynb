# %% [markdown]
# Program1.ipynb

# %%
print("Hello World")
# Out:
# Hello World

# %%
num = 100
print(num)
# Out:
# 100

# %%
num
# Out:
# 100

# %%
print(f"num = {num}")
# Out:
# num = 100

# %%
a = 20
b = 40
print(a+b)
# Out:
# 60

# %%
a = 10
b = 20
print(a * b)
# Out:
# 200

# %%
a = 10
b = 20
print(a / b)
# Out:
# 0.5

# %%
a = 10
b = 20
print(a % b)
# Out:
# 10

# %%
a = 10
b = 20
print(a - b)
# Out:
# -10
