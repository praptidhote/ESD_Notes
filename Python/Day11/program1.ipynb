# %% [markdown]
# # Pandas

# %% [markdown]
# ## series and DataFrame

# %%
# import the required packages

import numpy as np
import pandas as pd

# %%
# prerequisities

import warnings
warnings.filterwarnings(action="ignore")
