# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
import warnings 

warnings.filterwarnings(action="ignore")

# %%
df=pd.read_csv("energy_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df=pd.read_csv("energy_dataset.csv")
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
x=df.drop(['test_result'],axis=1)

y=df["test_result"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 x=df.drop(['test_result'],axis=1)
#       3 y=df["test_result"]
#
# NameError: name 'df' is not defined

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=123456)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=123456)
#
# NameError: name 'train_test_split' is not defined

# %%
x_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x_train
#
# NameError: name 'x_train' is not defined

# %%
model = LogisticRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model = LogisticRegression()
#
# NameError: name 'LogisticRegression' is not defined

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.fit(X_train, y_train)
#
# NameError: name 'model' is not defined

# %%
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 y_pred = model.predict(X_test)
#
# NameError: name 'model' is not defined

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 accuracy = accuracy_score(y_test, y_pred)
#       2 print("Accuracy:", accuracy)
#
# NameError: name 'accuracy_score' is not defined

# %%
plt.scatter(range(len(y_test)), y_test, label="Actual")
plt.scatter(range(len(y_pred)), y_pred, label="Predicted")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plt.scatter(range(len(y_test)), y_test, label="Actual")
#       2 plt.scatter(range(len(y_pred)), y_pred, label="Predicted")
#       3 plt.legend()
#
# NameError: name 'plt' is not defined
